# %% [markdown]
# # Menyiapkan Library

# %%
#Import library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
#Memuat tabel customer

customers_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/customers.csv")
customers_df.head()
# Out:
#    customer_id customer_name             gender  age  \
# 0            1       fulan 1             Female   30
# 1            2       fulan 2  Prefer not to say   69
# 2            3       fulan 3  Prefer not to say   59
# 3            4       fulan 4  Prefer not to say   67
# 4            5       fulan 5  Prefer not to say   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %%
#Memuat tabel orders

orders_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/orders.csv")
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %%
#Memuat tabel product

product_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/products.csv")
product_df.head()
# Out:
#    product_id product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %%
#Memuat tabel sales

sales_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/sales.csv")
sales_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2        212.0
# 1         1         1         481             118         1        118.0
# 2         2         1           2              96         3        288.0
# 3         3         1        1002             106         2        212.0
# 4         4         1         691             113         3        339.0

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Menilai tabel customers_df

# %%
#Menilai data customers_df

customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB

# %% [markdown]
# Tipe data tidak bermasalah
# Ada perbedaan jumlah data pada kolom gender sehingga menunjukkan adanya missing values pada kolom tersebut

# %%
#Memuat informasi jumlah missing values

customers_df.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %% [markdown]
# Terdapat sebanyak 18 missing values pada kolom gender

# %%
#Memeriksa duplikasi data

print("Jumlah duplikasi data : ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi data :  6

# %% [markdown]
# Terdapat sebanyak 6 duplikasi data yang terjadi

# %%
#Memeriksa parameter statistik dari kolom numerik yang ada pada tabel customers_df

customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1007.000000  1007.000000  1007.000000
# mean    501.726912    50.929494  5012.538232
# std     288.673238    30.516299  2885.836112
# min       1.000000    20.000000     2.000000
# 25%     252.500000    34.000000  2403.500000
# 50%     502.000000    50.000000  5087.000000
# 75%     751.500000    65.000000  7493.500000
# max    1000.000000   700.000000  9998.000000

# %% [markdown]
# Terdapat keanehan pada nilai yang maksimum pada kolom age. Ini merupakan masalah inaccurate data. (umur manusia kok bisa sampe 700?)

# %% [markdown]
# #### Menilai tabel orders_df

# %%
#Menilai data pada tabel orders_df

orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %% [markdown]
# Tidak ada missing values pada tabel orders_df. Namun, tipe data pada kolom order_date dan delivery_date tidak sesuai. Seharusnya menggunakan tipe data datetime

# %%
#Memeriksa jumlah duplikasi data pada tabel dan ringkasan parameter

print("Jumlah duplikasi data : ", orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi data :  0
#           order_id  customer_id       payment
# count  1000.000000  1000.000000   1000.000000
# mean    500.500000   506.640000  33972.936000
# std     288.819436   277.115502  14451.609047
# min       1.000000     1.000000  10043.000000
# 25%     250.750000   275.250000  21329.250000
# 50%     500.500000   515.000000  33697.500000
# 75%     750.250000   737.250000  46249.000000
# max    1000.000000  1000.000000  59910.000000

# %% [markdown]
# Tidak ada duplikasi data dan keanehan pada tabel orders_df

# %% [markdown]
# #### Menilai tabel product_df

# %%
#Menilai tabel product_df

product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1266 non-null   int64
#  1   product_type  1266 non-null   object
#  2   product_name  1266 non-null   object
#  3   size          1266 non-null   object
#  4   colour        1266 non-null   object
#  5   price         1266 non-null   int64
#  6   quantity      1266 non-null   int64
#  7   description   1266 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 79.3+ KB

# %% [markdown]
# Tidak ada missing values dan keanehan pada tabel product_df.

# %%
#Memeriksa duplikasi dan ringkasan parameter

print("Jumlah duplikasi data : ", product_df.duplicated().sum())
product_df.describe()
# Out:
# Jumlah duplikasi data :  6
#         product_id        price     quantity
# count  1266.000000  1266.000000  1266.000000
# mean    627.926540   105.812006    60.138231
# std     363.971586     9.715611    11.682791
# min       0.000000    90.000000    40.000000
# 25%     313.250000    95.250000    50.000000
# 50%     626.500000   109.000000    60.000000
# 75%     942.750000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000

# %% [markdown]
# Terdapat sebanyak 6 duplikasi data pada tabel product_df

# %% [markdown]
# #### Menilai tabel sales_df

# %%
#Memeriksa missing values dan keanehan

sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     4981 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB

# %% [markdown]
# Terdapat perbedaan pada kolom total_price yang menunjukkan adanya missing values

# %%
#Memeriksa jumlah missing values

sales_df.isna().sum()
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %% [markdown]
# Data menunjukkan ada sebanyak 19 missing values yang terjadi pada kolom total_price

# %%
#Memeriksa duplikasi data dan parameter statistik

print("Jumlah duplikasi data : ", sales_df.duplicated().sum())
sales_df.describe()
# Out:
# Jumlah duplikasi data :  0
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  4981.000000
# mean    206.307368
# std      86.352449
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# Data menunjukkan tidak ada duplikasi data dan keanehan pada tabel sales_df

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Membersihkan Data customers_df

# %% [markdown]
# #### duplicate data

# %%
customers_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi data : ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi data :  0

# %% [markdown]
# duplikasi data sudah tidak ada

# %% [markdown]
# #### missing value

# %%
#melakukan filtering untuk melihat data yang mengandung missing value

customers_df[customers_df.gender.isna()]
# Out:
#      customer_id customer_name gender  age                     home_address  \
# 38            39      fulan 39    NaN   80  7440 Cameron Estate DrSuite 628
# 167          168     fulan 168    NaN   27         2781 Berge MallSuite 452
# 322          322     fulan 322    NaN   30        593 Becker CircleApt. 333
# 393          393     fulan 393    NaN   34          5158 Levi HillSuite 531
# 442          442     fulan 442    NaN   26           5157 Feil RoadApt. 633
# 722          720     fulan 720    NaN   40         31 Jordan ParadeApt. 400
# 745          743     fulan 743    NaN   57   09 Christopher StreetSuite 967
# 773          771     fulan 771    NaN   74     7367 Wright JunctionApt. 773
# 798          795     fulan 795    NaN   49          487 Summer MewsApt. 874
# 801          798     fulan 798    NaN   56           27 Aiden KnollApt. 875
# 825          822     fulan 822    NaN   59        41 Jenkins KnollSuite 438
# ...

# %% [markdown]
# Baris data yang memiliki missing values pada kolom gender masih mengandung banyak informasi penting sehingga tidak bisa langsung dibuang. Metode yang tepat untuk mengatasi masalah ini dengan menggunakan imputation

# %%
#menggunakan method untuk mengidentifikasi nilai yang dominan

customers_df.gender.value_counts()
# Out:
# Prefer not to say    725
# Male                 143
# Female               115
# Name: gender, dtype: int64

# %% [markdown]
# nilai yang dominan adalah Prefer not to say, yang artinya dominasi customer tidak mau memberitahukan usia mereka. Gunakan nilai dominan ini untuk mengisi data yang hilang

# %%
#mengisi missing values dengan nilai dominan dan mengecek kondisi missing values

customers_df.fillna(value="Prefer not to say", inplace=True)
customers_df.isna().sum()
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %% [markdown]
# Sudah tidak ada missing values lagi

# %% [markdown]
# #### inaccurate value

# %%
#memfilter data yang mengandung inaccurate value pada kolom age

customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 967          961     fulan 961  Prefer not to say  700
#
#                    home_address  zip_code        city            state  \
# 967  29 Farrell ParadeSuite 818      6528  New Joseph  South Australia
#
#        country
# 967  Australia

# %% [markdown]
# Asumsi bahwa nilai 700 pada kolom age adalah human error. Bisa jadi pengguna kelebihan memasukkan angka 0 saat proses input data

# %%
#mengatasi inaccurate dengan mengganti nilai
customers_df.age.replace(customers_df.age.max(), 70, inplace=True)

# %%
#mengecek kembali
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 215          216     fulan 216  Prefer not to say  500
#
#                home_address  zip_code       city               state  \
# 215  038 Haley MewsApt. 810      3991  Bayertown  Northern Territory
#
#        country
# 215  Australia

# %% [markdown]
# Sudah tidak ada nilai yang mencurigakan / tidak masuk akal

# %%
#memastikan dengan melihat parameter statistik kembali
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1001.000000  1001.000000  1001.000000
# mean    500.942058    50.323676  5000.693307
# std     289.013599    22.665946  2886.084454
# min       1.000000    20.000000     2.000000
# 25%     251.000000    34.000000  2398.000000
# 50%     501.000000    50.000000  5079.000000
# 75%     751.000000    65.000000  7454.000000
# max    1000.000000   500.000000  9998.000000

# %% [markdown]
# nilai max pada kolom age sudah cukup masuk akal

# %% [markdown]
# ### Membersikan data orders_df

# %% [markdown]
# #### kesalahan tipe data

# %%
#mengubah tipe data pada kolom yang memiliki kesalahan tipe data

datetime_columns = ["order_date", "delivery_date"]

for column in datetime_columns:
    orders_df[column] = pd.to_datetime(orders_df[column])

# %%
#memastikan tipe data sudah benar
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   datetime64[ns]
#  4   delivery_date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 39.2 KB

# %% [markdown]
# Tipe data pada kolom order_date dan delivery_date sudah benar

# %% [markdown]
# ### Membersihkan data product_df

# %%
#mengapus duplikasi data dengan drop

product_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi data : ", product_df.duplicated().sum())
# Out:
# Jumlah duplikasi data :  0

# %% [markdown]
# Sudah tidak ada duplikasi data pada tabel product_df

# %% [markdown]
# ### Membersihkan data sales_df

# %% [markdown]
# #### missing values

# %%
#memfilter data yang memiliki missing values

sales_df[sales_df.total_price.isna()]
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 9            9         2        1196             105         1          NaN
# 121        121        27        1027              90         3          NaN
# 278        278        63         360              94         2          NaN
# 421        421        95        1091             115         1          NaN
# 489        489       108        1193             105         3          NaN
# 539        539       117         405             119         2          NaN
# 636        636       134         653              93         3          NaN
# 687        687       145        1138             102         1          NaN
# 854        854       177          64             104         1          NaN
# 1079      1079       222         908              94         3          NaN
# 1193      1193       248        1121             102         2          NaN
# ...

# %% [markdown]
# Dari data tersebut, kita mencari nilai total_price seharusnya. Nilai pada kolam total_price merupakan hasil perkalian antara price_per_unit dan quantity. Maka, missing values pada kolom total_price dapat diisi dengan mengalikan kedua kolom yang berkaitan

# %%
#mengalikan dua kolom untuk mengisi missing values

sales_df["total_price"] = sales_df["price_per_unit"] * sales_df["quantity"]

# %%
#memastikan hasil 

sales_df.isna().sum()
# Out:
# sales_id          0
# order_id          0
# product_id        0
# price_per_unit    0
# quantity          0
# total_price       0
# dtype: int64

# %% [markdown]
# Sudah tidak ada missing values pada tabel sales_df

# %% [markdown]
# # SELESAI DATA WRANGLING

# %% [markdown]
# # EXPLORATORY DATA ANALYSYS

# %% [markdown]
# ### Eksplorasi data customers_df

# %%
customers_df.describe(include="all")
# Out:
#         customer_id customer_name             gender          age  \
# count   1001.000000          1001               1001  1001.000000
# unique          NaN          1000                  3          NaN
# top             NaN     fulan 943  Prefer not to say          NaN
# freq            NaN             2                743          NaN
# mean     500.942058           NaN                NaN    50.323676
# std      289.013599           NaN                NaN    22.665946
# min        1.000000           NaN                NaN    20.000000
# 25%      251.000000           NaN                NaN    34.000000
# 50%      501.000000           NaN                NaN    50.000000
# 75%      751.000000           NaN                NaN    65.000000
# max     1000.000000           NaN                NaN   500.000000
#
#                       home_address     zip_code     city            state  \
# count                         1001  1001.000000     1001             1001
# ...

# %% [markdown]
# Dari rangkuman tersebut, terlihat ada keanehan data pada kolom age yakni nilai maxnya 500. Ini merupakan inaccurate value sehingga harus diatasi (umur manusia tidak mungkin sampai 500 tahun kecuali sakti)

# %%
#melakukan filter pada inaccurate value 

customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 215          216     fulan 216  Prefer not to say  500
#
#                home_address  zip_code       city               state  \
# 215  038 Haley MewsApt. 810      3991  Bayertown  Northern Territory
#
#        country
# 215  Australia

# %% [markdown]
# Diasumsikan nilai 500 merupakan human error yang bisa jadi kesalahan input. (kelebihan masukkan nilai 0)

# %%
#mengganti nilai max dengan nilai yang relevan
customers_df.age.replace(customers_df.age.max(), 50, inplace=True)

# %%
#mengecek kembali rangkuman parameter statistik

customers_df.describe(include="all")
# Out:
#         customer_id customer_name             gender          age  \
# count   1001.000000          1001               1001  1001.000000
# unique          NaN          1000                  3          NaN
# top             NaN     fulan 943  Prefer not to say          NaN
# freq            NaN             2                743          NaN
# mean     500.942058           NaN                NaN    49.874126
# std      289.013599           NaN                NaN    17.644663
# min        1.000000           NaN                NaN    20.000000
# 25%      251.000000           NaN                NaN    34.000000
# 50%      501.000000           NaN                NaN    50.000000
# 75%      751.000000           NaN                NaN    65.000000
# max     1000.000000           NaN                NaN    80.000000
#
#                       home_address     zip_code     city            state  \
# count                         1001  1001.000000     1001             1001
# ...

# %% [markdown]
# Data sudah terlihat masuk akal dengan nilai maksimal pada kolom age adalah 80.
#
# Kemudian dari rangkuman tersebut diperoleh informasi jumlah pelanggan sebanyak 1001 orang dengan kisaran umur 20 tahun hingga 80 tahun (lihat di kolom age). Rata - rata umur pelanggan adalah 49.87 tahun dengan standar deviasinya 17.64 tahun.
#
# Ini menunjukkan bahwa segmentasi pelanggan yang ada cukup luas mencakup remaja hingga lansia

# %%
#melihat demografi pelanggan berdasarkan jenis kelamin (gender) dengan membuat pivot tabel

customers_df.groupby(by="gender").agg({
    "customer_id": "nunique",
    "age": ["max", "min", "mean", "std"]
})
# Out:
#                   customer_id age
#                       nunique max min       mean        std
# gender
# Female                    115  79  20  49.147826  16.646607
# Male                      143  80  20  51.230769  18.462635
# Prefer not to say         742  80  20  49.725437  17.644283

# %% [markdown]
# Pelanggan didominasi oleh "prefer not to say" yang berarti dominasi pelanggan tidak mau menyebutkan gender mereka. Distribusi umur dari seluruh data gender pun mirip yakni berkisar antara umur 20 tahun hingga 80 tahun.

# %%
#melihat persebaran data jumlah pelanggan berdasarkan kota (city)

customers_df.groupby(by="city").customer_id.nunique().sort_values(ascending=False)
# Out:
# city
# East Aidan       3
# East Sophia      3
# New Ava          3
# West Jackfort    2
# Corkeryshire     2
#                 ..
# Jordanside       1
# Josephland       1
# Josephmouth      1
# Justinport       1
# Zacville         1
# Name: customer_id, Length: 961, dtype: int64

# %%
#melihat persebaran data jumlah pelanggan berdasarkan negara bagian (state)

customers_df.groupby(by="state").customer_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 139
# Queensland                      134
# New South Wales                 132
# Northern Territory              125
# Western Australia               124
# Australian Capital Territory    121
# Victoria                        121
# Tasmania                        104
# Name: customer_id, dtype: int64

# %% [markdown]
# Berdasarkan hasil, persebaran data pelanggan cukup merata di setiap kota dan negara bagian.
#
# Pelanggan paling banyak berada di Kota East Aidan, East Sophia, dan New Ava dengan masing - masing 3 pelanggan. Di sisi lain pelanggan paling banyak berada di negara bagian South Australia dengan 139 pelanggan.

# %% [markdown]
# ### Eksplorasi Data orders_df

# %%
#membuat kolom baru untuk memuat waktu pengiriman tiap order

delivery_time = orders_df["delivery_date"] - orders_df["order_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0

# %% [markdown]
# Terlihat kolom baru delivery_time
#
# proses :
# menghitung selisih antara delivery_date dengan order_date menyimpan sebagai delivery_time (dibuat kolom baru)
#
# menghitung jumlah detik dari delivery_time kemudian diubah ke satuan hari dan diambil nilai bulatnya.

# %%
#memperoleh rangkuman statistik

orders_df.describe(include="all",datetime_is_numeric=True)
# Out:
#           order_id  customer_id       payment                  order_date  \
# count  1000.000000  1000.000000   1000.000000                        1000
# mean    500.500000   506.640000  33972.936000  2021-05-27 18:38:52.800000
# min       1.000000     1.000000  10043.000000         2021-01-01 00:00:00
# 25%     250.750000   275.250000  21329.250000         2021-03-13 18:00:00
# 50%     500.500000   515.000000  33697.500000         2021-05-27 12:00:00
# 75%     750.250000   737.250000  46249.000000         2021-08-12 06:00:00
# max    1000.000000  1000.000000  59910.000000         2021-10-24 00:00:00
# std     288.819436   277.115502  14451.609047                         NaN
#
#              delivery_date  delivery_time
# count                 1000    1000.000000
# mean   2021-06-10 20:31:12      14.078000
# min    2021-01-03 00:00:00       1.000000
# 25%    2021-03-28 00:00:00       8.000000
# 50%    2021-06-11 12:00:00      14.000000
# 75%    2021-08-24 06:00:00      21.000000
# ...

# %% [markdown]
# Berdasarkan rangkuman, rata - rata waktu pengiriman adalah 14 hari dengan waktu pengiriman paling lama 27 hari (max) dan paling cepat 1 hari (min)

# %% [markdown]
# ### Eksplorasi Data orders_df dan customers_df

# %%
#mengategorikan pelanggan yang sudah pernah order dan belum pernah order dengan membuat kolom baru

customer_id_in_orders_df = orders_df.customer_id
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")
customers_df.sample(5)
# Out:
#      customer_id customer_name             gender  age  \
# 329          329     fulan 329  Prefer not to say   53
# 88            89      fulan 89             Female   51
# 198          199     fulan 199  Prefer not to say   65
# 717          715     fulan 715  Prefer not to say   61
# 296          297     fulan 297  Prefer not to say   22
#
#                       home_address  zip_code               city  \
# 329  3203 Jackson TerraceSuite 580      5466  South Claudialand
# 88         1290 Koch GroveApt. 799      1443        Lake Hannah
# 198        94 Hannah LoopSuite 177      6219    Lake Declanland
# 717      1029 Eva JunctionApt. 767      8927        Port Hunter
# 296          06 Koss HillSuite 888      5754           Owentown
#
#                             state    country  status
# 329             Western Australia  Australia  Active
# 88                     Queensland  Australia  Active
# 198               South Australia  Australia  Active
# ...

# %%
#mencari jumlah pelanggan aktif dan non-aktif

customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active        1000
# Non Active       1
# Name: customer_id, dtype: int64

# %% [markdown]
# Dari hasil pivot table, hanya ada 1 pelanggan yang tidak aktif atau belum melakukan transaksi.

# %%
#menggabungkan kedua tabel untuk memperoleh lebih banyak informasi

orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time  \
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0
#
#   customer_name             gender  age                   home_address  \
# 0      fulan 64  Prefer not to say   75      4927 Alice MeadowApt. 960
# 1     fulan 473               Male   61  531 Schmitt BoulevardApt. 010
# 2     fulan 774  Prefer not to say   34       2096 Wilson MewsApt. 714
# 3     fulan 433  Prefer not to say   46        5777 Mayer PassApt. 881
# 4     fulan 441  Prefer not to say   53   33 Richards JunctionApt. 478
#
#    zip_code                city              state    country  status
# ...

# %%
#mencari jumlah order berdasarkan kota

orders_customers_df.groupby(by="city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#                city  order_id
# 0        Jordanside         6
# 1           New Ava         6
# 2         Lake Rose         5
# 3        O'keefeton         5
# 4          East Max         5
# 5  Port Hannahburgh         5
# 6          Rubyfort         5
# 7          West Kai         5
# 8     Andrewborough         4
# 9     Port Aaronton         4

# %% [markdown]
# Berdasarkan pivot table, Kota Jordanside dan New Ava merupakan dua kota dengan jumlah order terbanyak.

# %%
#mencari jumlah order berdasarkan negara bagian

orders_customers_df.groupby(by="state").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#                           state  order_id
# 0               South Australia       148
# 1                    Queensland       139
# 2             Western Australia       130
# 3               New South Wales       129
# 4  Australian Capital Territory       118
# 5                      Victoria       118
# 6                      Tasmania       112
# 7            Northern Territory       106

# %% [markdown]
# Negara bagian South Australia merupakan negara bagian dengan jumlah order terbanyak

# %%
#mencari jumlah order berdasarkan gender
orders_customers_df.groupby(by="gender").order_id.nunique().sort_values(ascending=False)
# Out:
# gender
# Prefer not to say    725
# Female               139
# Male                 136
# Name: order_id, dtype: int64

# %% [markdown]
# Kebanyakan order dilakukan oleh pelanggan yang tidak mau memberitahu jenis kelamin mereka.

# %%
#mencari jumlah order berdasarkan kelompok usia

orders_customers_df["age_group"] = orders_customers_df.age.apply(lambda x: "Youth" if x <= 24 else ("Seniors" if x > 64 else "Adults"))
orders_customers_df.groupby(by="age_group").order_id.nunique().sort_values(ascending=False)
# Out:
# age_group
# Adults     681
# Seniors    226
# Youth       93
# Name: order_id, dtype: int64

# %% [markdown]
# Pelanggan yang melakukan order kebanyakan dari kelompok usia adults yakni yang memiliki kisaran umur 24 sampai 64

# %% [markdown]
# ### Eksplorasi data product_df dan sales_df

# %%
product_df.describe(include="all")
# Out:
#          product_id product_type product_name  size colour        price  \
# count   1260.000000         1260         1260  1260   1260  1260.000000
# unique          NaN            3           35     8      7          NaN
# top             NaN        Shirt        Denim    XS    red          NaN
# freq            NaN          420           70   252    180          NaN
# mean     629.500000          NaN          NaN   NaN    NaN   105.805556
# std      363.874979          NaN          NaN   NaN    NaN     9.704423
# min        0.000000          NaN          NaN   NaN    NaN    90.000000
# 25%      314.750000          NaN          NaN   NaN    NaN    95.750000
# 50%      629.500000          NaN          NaN   NaN    NaN   108.500000
# 75%      944.250000          NaN          NaN   NaN    NaN   114.000000
# max     1259.000000          NaN          NaN   NaN    NaN   119.000000
#
#            quantity                                   description
# ...

# %% [markdown]
# Ringkasan parameter statistik menunjukkan harga product berkisar antara 90 dolar sampai 119 dolar. (lihat nilai min dan max pada kolom price)

# %%
sales_df.describe(include="all")
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  5000.000000
# mean    206.360000
# std      86.357457
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# Ringkasan tersebut menunjukkan informasi menarik pelanggan paling banyak membeli tiga buah item dalam satu jenis produk dengan total harga 357 dolar. Lihat pada nilai max kolom quantity dan total_price

# %%
#mencari produk dengan harga termahal dan terendah
product_df.sort_values(by="price", ascending=False)
# Out:
#       product_id product_type product_name size  colour  price  quantity  \
# 704          698       Jacket        Parka    L  violet    119        53
# 671          665       Jacket        Parka   XS     red    119        65
# 698          692       Jacket        Parka    M  indigo    119        66
# 699          693       Jacket        Parka    L  indigo    119        44
# 700          694       Jacket        Parka   XL  indigo    119        78
# ...          ...          ...          ...  ...     ...    ...       ...
# 1225        1219     Trousers      Pleated   XL  indigo     90        45
# 1226        1220     Trousers      Pleated   XS  violet     90        58
# 1227        1221     Trousers      Pleated    S  violet     90        50
# 1228        1222     Trousers      Pleated    M  violet     90        45
# 599          593       Jacket       Bomber    L  violet     90        68
#
#                                         description
# ...

# %% [markdown]
# Data di atas menunjukkan produk dengan harga termahal yaitu Parka dengan harga 119 dolar. Sedangkan produk dengan harga termurah yaitu Bomber dengan harga 90 dolar.

# %%
#mencari informasi terkait produk berdasar tipe dan nama produk dengan pivot

product_df.groupby(by="product_type").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price": ["min", "max"]
})
# Out:
#              product_id quantity price
#                 nunique      sum   min  max
# product_type
# Jacket              420    25387    90  119
# Shirt               420    25263    92  119
# Trousers            420    25139    90  119

# %%
product_df.groupby(by="product_name").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price": ["min", "max"]
})
# Out:
#                   product_id quantity price
#                      nunique      sum   min  max
# product_name
# Bomber                    35     2083    90   90
# Camp Collared             35     2071   112  112
# Cardigan                  35     2032   118  118
# Cargo Pants               35     2146   106  106
# Casual Slim Fit           35     2086   113  113
# Chambray                  35     2020   105  105
# Chinos                    35     2101   100  100
# Coach                     35     2158   115  115
# Cords                     35     2260   113  113
# Cropped                   35     2085    99   99
# Cuban Collar              35     2017    93   93
# Denim                     70     4204    92  115
# Drawstring                35     2042   104  104
# Dress                     35     2125   119  119
# Flannel                   35     2135    96   96
# Henley                    35     2051    92   92
# High-Waisted              35     2198    98   98
# ...

# %%
#mencari produk yang paling laris

sales_product_df = pd.merge(
    left=sales_df,
    right=product_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sales_product_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  price  quantity_y  \
# 0        Shirt      Chambray    L  orange    105          44
# 1       Jacket        Puffer    S  indigo    110          62
# 2        Shirt  Oxford Cloth    M     red    114          54
# 3     Trousers          Wool    M    blue    111          52
# 4       Jacket         Parka    S  indigo    119          53
#
#                                    description
# 0   A orange coloured, L sized, Chambray Shirt
# 1    A indigo coloured, S sized, Puffer Jacket
# ...

# %% [markdown]
# Terdapat perbedaan antara price dan price_unit, hal ini bisa terjadi karena potongan harga, biaya operasional, atau yang lainnya

# %%
#mencari informasi penjualan produk berdasar tipe

sales_product_df.groupby(by="product_type").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#               sales_id  quantity_x  total_price
# product_type
# Jacket            1676        3343       357026
# Shirt             1641        3259       333600
# Trousers          1683        3360       341174

# %% [markdown]
# Dari pivot tabel di atas, didapatkan informasi bahwa Trousers merupakan produk yang paling laris. Namun, jika dilihat berdasarkan revenue, maka Jacket adalah product yang paling banyak menyumbag revenue bagi perusahaan

# %%
#mencari informasi penjualan berdasar nama produk

sales_product_df.groupby(by="product_name").agg({
    "product_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
}).sort_values(by="total_price", ascending=False)
# Out:
#                    product_id  quantity_x  total_price
# product_name
# Denim                      67         527        52399
# Casual Slim Fit            35         306        36414
# Trench Coat                33         299        35581
# Shearling                  34         302        35334
# Puffer                     34         298        35164
# Flannel                    34         281        33158
# Cropped                    35         284        32660
# Pleated                    35         308        32340
# Joggers                    34         334        31062
# Chambray                   34         290        30740
# Parka                      35         269        30397
# Bomber                     35         297        29700
# Chinos                     34         260        29380
# Windbreaker                35         287        29274
# Cardigan                   34         260        29120
# Peacoat                    31         266        28994
# ...

# %% [markdown]
# Denim merupakan barang paling laris dan menyumbang revenue paling banyak bagi perusahaan

# %% [markdown]
# ### Eksplorasi Data all_df

# %%
#menggabungkan semua data dari DataFrame

all_df = pd.merge(
    left=sales_product_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  ...  customer_name  \
# 0        Shirt      Chambray    L  orange  ...       fulan 64
# 1       Jacket        Puffer    S  indigo  ...       fulan 64
# 2        Shirt  Oxford Cloth    M     red  ...       fulan 64
# 3     Trousers          Wool    M    blue  ...       fulan 64
# 4       Jacket         Parka    S  indigo  ...       fulan 64
#
#               gender age               home_address  zip_code            city  \
# ...

# %%
#melihat preferensi pembelian berdasarkan state dan product type

all_df.groupby(by=["state", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                            quantity_x  total_price
# state                        product_type
# Australian Capital Territory Jacket               406        43204
#                              Shirt                396        40448
#                              Trousers             454        46790
# New South Wales              Jacket               451        47998
#                              Shirt                431        43980
#                              Trousers             392        39766
# Northern Territory           Jacket               365        38991
#                              Shirt                336        33865
#                              Trousers             384        38998
# Queensland                   Jacket               499        53511
#                              Shirt                417        42506
#                              Trousers             453        46045
# ...

# %% [markdown]
# Tipe produk Jacket paling banyak dibeli di negara bagian Queensland, South Australia, dan New South Wales
#
# Tipe produk Shirt paling banyak dibeli di South Australia, New South Wales, dan Queensland
#
# Tipe produk Trousers paling banyak dibeli di South Australia, Australian Capital Territory, dan Queensland

# %%
#melihat selera tipe produk berdasar gender

all_df.groupby(by=["gender", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                 quantity_x  total_price
# gender            product_type
# Female            Jacket               481        50963
#                   Shirt                445        45146
#                   Trousers             481        49295
# Male              Jacket               480        50978
#                   Shirt                410        41939
#                   Trousers             453        46071
# Prefer not to say Jacket              2382       255085
#                   Shirt               2404       246515
#                   Trousers            2426       245808

# %% [markdown]
# Semua produk paling banyak dibeli oleh mereka yang tidak mau memberitahukan gender mereka

# %%
#melihat selera tipe produk berdasar kelompok usia

all_df.groupby(by=["age_group", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                         quantity_x  total_price
# age_group product_type
# Adults    Jacket              2292       245055
#           Shirt               2225       227781
#           Trousers            2272       231271
# Seniors   Jacket               777        82959
#           Shirt                733        74977
#           Trousers             766        77471
# Youth     Jacket               274        29012
#           Shirt                301        30842
#           Trousers             322        32432

# %% [markdown]
# Semua produk paling banyak dibeli oleh mereka dengan kelompok usia Adults atau yang berkisar umur 24 sampai 63

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# #### 1. Bagaimana Performa Penjualan dan Revenue Perusahaan dalam Beberapa Bulan Terakhir

# %%
monthly_orders_df = all_df.resample(rule='M', on='order_date').agg({
    "order_id": "nunique",
    "total_price": "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%Y-%m')
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "total_price": "revenue"
}, inplace=True)
monthly_orders_df.head()
# Out:
#   order_date  order_count  revenue
# 0    2021-01          109   119333
# 1    2021-02           93    95080
# 2    2021-03          117   131364
# 3    2021-04           99    97530
# 4    2021-05           84    85597

# %%
#membuat visualisasi

monthly_orders_df = all_df.resample(rule='M', on='order_date').agg({
    "order_id": "nunique",
    "total_price": "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%B') #mengubah format order date menjadi nama bulan

monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "total_price": "revenue"
}, inplace=True)

plt.figure(figsize=(10, 5))
plt.plot(monthly_orders_df["order_date"], monthly_orders_df["order_count"], marker='o', linewidth=2, color="blue")
plt.title("Number of Orders per Month (2021)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# Berdasarkan visualisasi tersebut, dapat disimpulkan bahwa jumlah order terbanyak terjadi di bulan Maret. Terdapat juga penurunan order yang signifikan pada bulan Februari, April, Mei, dan Oktober. Penurunan order ini pasti berdampak pada total revenue perusahaan

# %%
#melakukan validasi dengan melihat revenue perusahaan perbulan di tahun 2021

plt.figure(figsize=(10, 5))
plt.plot(
    monthly_orders_df["order_date"],
    monthly_orders_df["revenue"],
    marker="o",
    linewidth=2,
    color="blue"
)
plt.title("Total Revenue per Month (2021)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# Terlihat pada visualisasi, revenue terbesar perusahaan terjadi pada bulan Maret. Kemudian terjadi penurunan yang sangat signifikan pada bulan Februari, April, Mei, dan Oktober. Ini merupakan akibat dari penurunan order yang ada pada visualisasi sebelumnya.

# %% [markdown]
# #### Produk Apa yang Paling Banyak dan Paling Sedikit Terjual?

# %%
#membuat DataFrame jumlah penjualan tiap produk
sum_order_item_df = all_df.groupby("product_name").quantity_x.sum().sort_values(ascending=False).reset_index()
sum_order_item_df.head(15)
# Out:
#        product_name  quantity_x
# 0             Denim         527
# 1           Joggers         334
# 2           Pleated         308
# 3   Casual Slim Fit         306
# 4         Shearling         302
# 5       Relaxed Leg         301
# 6       Trench Coat         299
# 7            Puffer         298
# 8            Bomber         297
# 9          Chambray         290
# 10     Oxford Cloth         289
# 11       Drawstring         288
# 12         Slim-Fit         288
# 13      Windbreaker         287
# 14          Cropped         284

# %% [markdown]
# DataFrame menunjukkan urutan produk mulai dari yang paling banyak terjual hingga yang paling sedikit terjual dalam 15 data pertama. Denim menjadi produk yang paling banyak terjual dengan total penjualan sebanyak 527 item dan Cropped menjadi produk yang paling sedikit terjual dengan total penjualan sebanyak 284 item.

# %%
#membuat visualisasi dalam bentuk chart bar
#membuat dua ruang visualisasi untuk melihat performa terbaik dan terburuk

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

# %%
#mengisi kanvas kosong dengan bar chart
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="quantity_x", y="product_name", data=sum_order_item_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis='y', labelsize=12)


sns.barplot(x="quantity_x", y="product_name", data=sum_order_item_df.sort_values(by="quantity_x", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()

# %% [markdown]
# Visualisasi tersebut menunjukkan produk Denim merupakan produk yang paling banyak terjual dan Mandarin Collar merupakan produk yang paling sedikit terjual

# %% [markdown]
# #### Bagaimana Demografi Pelanggan yang Dimiliki?

# %%
#mengidentifikasi jumlah pelanggan berdasarkan gender

bygender_df = all_df.groupby(by="gender").customer_id.nunique().reset_index()
bygender_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)

plt.figure(figsize=(10, 5))

sns.barplot(
    y="customer_count",
    x="gender",
    data=bygender_df.sort_values(by="customer_count", ascending=False),
    palette=colors
)

plt.title("Number of Customer by Gender", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %% [markdown]
# Data tersebut menunjukkan mayoritas pelanggan tidak bersedia untuk memberitahukan informasi terkait gendernya

# %%
#mengidentifikasi data pelanggan berdasarkan usia

byage_df = all_df.groupby(by="age_group").customer_id.nunique().reset_index()
byage_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
byage_df['age_group'] = pd.Categorical(byage_df['age_group'], ["Youth", "Adults", "Seniors"])
plt.figure(figsize=(10, 5))
colors = ["#D3D3D3", "#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    y="customer_count",
    x="age_group",
    data=byage_df.sort_values(by="age_group", ascending=False),
    palette=colors
)

plt.title("Number of Customer by Age", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %% [markdown]
# Data tersebut menunjukkan mayoritas pelanggan adalah kelompok usia dewasa

# %%
#mengidentifikasi jumlah pelanggan berdasarkan state

bystate_df = all_df.groupby(by="state").customer_id.nunique().reset_index()
bystate_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
bystate_df
plt.figure(figsize=(10, 5))
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="customer_count",
    y="state",
    data=bystate_df.sort_values(by="customer_count", ascending=False),
    palette=colors
)

plt.title("Number of Customer by State", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()

# %% [markdown]
# Data tersebut menunjukkan pelanggan paling banyak berasal dari negara bagian South Australia

# %% [markdown]
# #### RFM Analysis

# %% [markdown]
# Metode untuk melakukan segmentasi pelanggan berdasar tiga parameter yakni recency, frequency, dan monetary
#
# recency : kapan terakhir pelanggan melakukan transaksi
# frequency : seberapa sering pelanggan melakukan transaksi
# monetary : seberapa besar revenue yang berasal dari pelanggan tsb
#
# dari 3 parameter, didapatkan pelanggan mana yang merupakan high value dan low value

# %%
#membuat dataframe untuk memperoleh informasi 3 parameter

rfm_df = all_df.groupby(by="customer_id", as_index=False).agg({
    "order_date": "max", #mengambil tanggal order terakhir
    "order_id": "nunique", #menghitung jumlah order
    "total_price": "sum", #menghitung jumlah revenue yg dihasilkan
})
rfm_df.columns = ["customer_id", "max_order_timestap", "frequency", "monetary"]

#menghitung kapan terakhir pelanggan melakukan transaksi
rfm_df["max_order_timestap"] = rfm_df["max_order_timestap"].dt.date
recent_date = orders_df["order_date"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestap"].apply(lambda x: (recent_date - x).days)

rfm_df.drop("max_order_timestap", axis=1, inplace=True)
rfm_df.head()
# Out:
#    customer_id  frequency  monetary  recency
# 0            1          3      1641      203
# 1            7          1      1017      156
# 2           10          1       270      229
# 3           11          1       382      149
# 4           12          1      1551      127

# %%
#mengidentifikasi best customer berdasarkan e parameter

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))
colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis='x', labelsize=15)

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()

# %%
all_df.to_csv("all_data.csv", index=False)
